# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris=iris.drop(["Id"],axis=1)

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import category_encoders as ce

# %%
ordinalencoder=ce.OrdinalEncoder(cols=["Species"])

# %%
iris=ordinalencoder.fit_transform(iris)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        1
# 1            4.9           3.0            1.4           0.2        1
# 2            4.7           3.2            1.3           0.2        1
# 3            4.6           3.1            1.5           0.2        1
# 4            5.0           3.6            1.4           0.2        1

# %%
iris.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species            int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
sns.scatterplot(data=iris,y="SepalLengthCm",x="SepalWidthCm",hue="Species")
plt.title("sepalwidth between 3 to 4.5 and sepal length between 4.5 to 6 classified as species as 1")
# Out:
# Text(0.5, 1.0, 'sepalwidth between 3 to 4.5 and sepal length between 4.5 to 6 classified as species as 1')

# %%
sns.scatterplot(data=iris,y="SepalLengthCm",x="PetalLengthCm",hue="Species")
plt.title("sepalLength between 5 to 7 and petallength between 3 to 5 classified as species as 2")
# Out:
# Text(0.5, 1.0, 'sepalLength between 5 to 7 and petallength between 3 to 5 classified as species as 2')

# %%
sns.scatterplot(data=iris,y="SepalWidthCm",x="PetalWidthCm",hue="Species")
plt.title("sepalwidth between 2 to 4.5 and petalwidth between 1.5 to 2.5 classified as species as 3")
# Out:
# Text(0.5, 1.0, 'sepalwidth between 2 to 4.5 and petalwidth between 1.5 to 2.5 classified as species as 3')

# %%
sns.kdeplot(data=iris,x="SepalLengthCm",shade=True,hue="Species")
# Out:
# /var/folders/qk/cbjnsy590pn24y_t34wv1t500000gn/T/ipykernel_35982/4256118027.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris,x="SepalLengthCm",shade=True,hue="Species")
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=iris,x="SepalWidthCm",shade=True,hue="Species")
# Out:
# /var/folders/qk/cbjnsy590pn24y_t34wv1t500000gn/T/ipykernel_35982/4032211314.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris,x="SepalWidthCm",shade=True,hue="Species")
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data=iris,x="PetalLengthCm",shade=True,hue="Species")
# Out:
# /var/folders/qk/cbjnsy590pn24y_t34wv1t500000gn/T/ipykernel_35982/3058030795.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris,x="PetalLengthCm",shade=True,hue="Species")
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=iris,x="SepalWidthCm",shade=True,hue="Species")
# Out:
# /var/folders/qk/cbjnsy590pn24y_t34wv1t500000gn/T/ipykernel_35982/4032211314.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris,x="SepalWidthCm",shade=True,hue="Species")
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
corr_matrix=iris.corr()

# %%
corr_matrix["Species"]
# Out:
# SepalLengthCm    0.782561
# SepalWidthCm    -0.419446
# PetalLengthCm    0.949043
# PetalWidthCm     0.956464
# Species          1.000000
# Name: Species, dtype: float64

# %%
iris_train,iris_test=train_test_split(iris,test_size=0.2,random_state=13)

# %%
X_train=iris_train.drop(["Species"],axis=1)
y_train=iris_train["Species"]
X_test=iris_test.drop(["Species"],axis=1)
y_test=iris_test["Species"]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix
print(accuracy_score(y_test,y_pred)*100)
#print(f1_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 96.66666666666667
# [[ 9  0  0]
#  [ 0  8  0]
#  [ 0  1 12]]
